# %%
'''# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
1 school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
2 sex - student's sex (binary: "F" - female or "M" - male)
3 age - student's age (numeric: from 15 to 22)
4 address - student's home address type (binary: "U" - urban or "R" - rural)
5 famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
6 Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)
7 Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
8 Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
9 Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
10 Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
11 reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
12 guardian - student's guardian (nominal: "mother", "father" or "other")
13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
16 schoolsup - extra educational support (binary: yes or no)
17 famsup - family educational support (binary: yes or no)
18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
19 activities - extra-curricular activities (binary: yes or no)
20 nursery - attended nursery school (binary: yes or no)
21 higher - wants to take higher education (binary: yes or no)
22 internet - Internet access at home (binary: yes or no)
23 romantic - with a romantic relationship (binary: yes or no)
24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
29 health - current health status (numeric: from 1 - very bad to 5 - very good)
30 absences - number of school absences (numeric: from 0 to 93)

# these grades are related with the course subject, Math or Portuguese:
31 G1 - first period grade (numeric: from 0 to 20)
31 G2 - second period grade (numeric: from 0 to 20)
32 G3 - final grade (numeric: from 0 to 20, output target)

'''
# Out:
# '# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:\n1 school - student\'s school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)\n2 sex - student\'s sex (binary: "F" - female or "M" - male)\n3 age - student\'s age (numeric: from 15 to 22)\n4 address - student\'s home address type (binary: "U" - urban or "R" - rural)\n5 famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)\n6 Pstatus - parent\'s cohabitation status (binary: "T" - living together or "A" - apart)\n7 Medu - mother\'s education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)\n8 Fedu - father\'s education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)\n9 Mjob - mother\'s job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or po
# ...

# %%
# Importing libraries needed

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#portuguese subject grades data os students

# %%
student_por=pd.read_csv("E:\\Machine learning\\student-por.csv",sep=";")

# %%
#maths subject grades of student

# %%
student_mat=pd.read_csv("E:\\Machine learning\\student-mat.csv",sep=";")

# %%
student_por.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %%
student_mat.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
student_mat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
student_por.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
#There were few students who studied both portuguese and maths, so merging the data to get new table of combined subjects as x and y grades columns

# %%
    list1=student_mat.columns
    list2=student_por.columns
    list3=[a for a in list1 if a in list2]
    list3.remove("G3")
    list3.remove("G2")
    list3.remove("G1")
    print(list3)
    print(len(list3))
# Out:
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences']
# 30

# %%
student=pd.merge(student_mat,student_por,on=list3,how='inner')

# %%
student.info()
student.head(40)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 0 to 38
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      39 non-null     object
#  1   sex         39 non-null     object
#  2   age         39 non-null     int64
#  3   address     39 non-null     object
#  4   famsize     39 non-null     object
#  5   Pstatus     39 non-null     object
#  6   Medu        39 non-null     int64
#  7   Fedu        39 non-null     int64
#  8   Mjob        39 non-null     object
#  9   Fjob        39 non-null     object
#  10  reason      39 non-null     object
#  11  guardian    39 non-null     object
#  12  traveltime  39 non-null     int64
#  13  studytime   39 non-null     int64
#  14  failures    39 non-null     int64
#  15  schoolsup   39 non-null     object
#  16  famsup      39 non-null     object
#  17  paid        39 non-null     object
#  18  activities  39 non-null     object
# ...

# %%
student_final=pd.merge(student_mat,student_por,on=list3,how='outer')
student.info()
student_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 0 to 38
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      39 non-null     object
#  1   sex         39 non-null     object
#  2   age         39 non-null     int64
#  3   address     39 non-null     object
#  4   famsize     39 non-null     object
#  5   Pstatus     39 non-null     object
#  6   Medu        39 non-null     int64
#  7   Fedu        39 non-null     int64
#  8   Mjob        39 non-null     object
#  9   Fjob        39 non-null     object
#  10  reason      39 non-null     object
#  11  guardian    39 non-null     object
#  12  traveltime  39 non-null     int64
#  13  studytime   39 non-null     int64
#  14  failures    39 non-null     int64
#  15  schoolsup   39 non-null     object
#  16  famsup      39 non-null     object
#  17  paid        39 non-null     object
#  18  activities  39 non-null     object
# ...

# %%
student_final.head(20)
student_both= student_final.dropna()
student_both.info()
student_both.head(10)
student_final.fillna(value=0,inplace=True)
# Filling zero values in the students grades of subjects they didnt attend
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 6 to 383
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      39 non-null     object
#  1   sex         39 non-null     object
#  2   age         39 non-null     int64
#  3   address     39 non-null     object
#  4   famsize     39 non-null     object
#  5   Pstatus     39 non-null     object
#  6   Medu        39 non-null     int64
#  7   Fedu        39 non-null     int64
#  8   Mjob        39 non-null     object
#  9   Fjob        39 non-null     object
#  10  reason      39 non-null     object
#  11  guardian    39 non-null     object
#  12  traveltime  39 non-null     int64
#  13  studytime   39 non-null     int64
#  14  failures    39 non-null     int64
#  15  schoolsup   39 non-null     object
#  16  famsup      39 non-null     object
#  17  paid        39 non-null     object
#  18  activities  39 non-null     object
# ...

# %%
'''Filtering out students who study both subjects from the combined table as it will be easy to remove those students from student_final table
since number of columns will also be same as well as row's indexes of students studying both subjects can be easily obtained and hence removed using drop method


'''
# Out:
# "Filtering out students who study both subjects from the combined table as it will be easy to remove those students from student_final table\nsince number of columns will also be same as well as row's indexes of students studying both subjects can be easily obtained and hence removed using drop method\n\n\n"

# %%
student_both.index
#student_final.drop(student_both.index,axis=0,inplace=True)
student_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1005 entries, 0 to 1004
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1005 non-null   object
#  1   sex         1005 non-null   object
#  2   age         1005 non-null   int64
#  3   address     1005 non-null   object
#  4   famsize     1005 non-null   object
#  5   Pstatus     1005 non-null   object
#  6   Medu        1005 non-null   int64
#  7   Fedu        1005 non-null   int64
#  8   Mjob        1005 non-null   object
#  9   Fjob        1005 non-null   object
#  10  reason      1005 non-null   object
#  11  guardian    1005 non-null   object
#  12  traveltime  1005 non-null   int64
#  13  studytime   1005 non-null   int64
#  14  failures    1005 non-null   int64
#  15  schoolsup   1005 non-null   object
#  16  famsup      1005 non-null   object
#  17  paid        1005 non-null   object
#  18  activities  1005 non-null   object
# ...

# %%
import math

#seperating students of maths subject
list_1=[]
for elements in student_final["G1_y"]:
    if elements==0:
        list_1.append(True)
    else:
        list_1.append(False)
        
#print(list_1)
student_maths=student_final[list_1]




# seperating students of portuguese subject

list_2=[]
for elements in student_final["G1_x"]:
    if elements==0:
        list_2.append(True)
    else:
        list_2.append(False)
        
#print(list_2)


student_port=student_final[list_2]

# %%
student_both.info()
student_maths.info()
student_port.info()
student_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 6 to 383
# Data columns (total 36 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      39 non-null     object
#  1   sex         39 non-null     object
#  2   age         39 non-null     int64
#  3   address     39 non-null     object
#  4   famsize     39 non-null     object
#  5   Pstatus     39 non-null     object
#  6   Medu        39 non-null     int64
#  7   Fedu        39 non-null     int64
#  8   Mjob        39 non-null     object
#  9   Fjob        39 non-null     object
#  10  reason      39 non-null     object
#  11  guardian    39 non-null     object
#  12  traveltime  39 non-null     int64
#  13  studytime   39 non-null     int64
#  14  failures    39 non-null     int64
#  15  schoolsup   39 non-null     object
#  16  famsup      39 non-null     object
#  17  paid        39 non-null     object
#  18  activities  39 non-null     object
# ...

# %%
# EDA of students studying both subjects

# %%
sns.barplot(x="school",y="G3_x",data=student_both)
#Mean score of GP school is higher than MS school in maths subject
plt.title("School wise comparison of Maths grades of students of both subjects")
plt.ylabel("Mean Maths grades")
# Out:
# Text(0, 0.5, 'Mean Maths grades')

# %%
sns.barplot(x="school",y="G3_y",data=student_both)
#Mean score of GP school is higher than MS school in portuguese subject
plt.title("School wise comparison of Portuguese grades of students of both subjects ")
plt.ylabel("Mean Portuguese grades")
# Out:
# Text(0, 0.5, 'Mean Portuguese grades')

# %%
school_GP=student_both[student_both["school"]=="GP"]
sns.countplot(x="sex",data=school_GP)
plt.title("Gender distribution in GP school students(both subjects)")

# Gender diversity graph in GP school shows good male female ratio studying both subjects
# Out:
# Text(0.5, 1.0, 'Gender distribution in GP school students(both subjects)')

# %%
school_MS=student_both[student_both["school"]=="MS"]
sns.countplot(x="sex",data=school_MS)
plt.title("Gender distribution in MS school students (both subjects)")
# Gender diversity graph shows female study both subject in large number as compared to boys of MS school
# Out:
# Text(0.5, 1.0, 'Gender distribution in MS school students (both subjects)')

# %%
print(len(student_both["sex"][student_both["sex"]=="M"])," are Males")
print(len(student_both["sex"][student_both["sex"]=="F"])," are Females")
g1=sns.countplot(x="sex",data=student_both)
plt.title("Gender distribution of GP & MS school (both subjects)")
# Gender diversity graph of both schools overall shows that female study both subjects more than males
# Out:
# 19  are Males
# 20  are Females
# Text(0.5, 1.0, 'Gender distribution of GP & MS school (both subjects)')

# %%
#Plotting stacked histograms by Schools on various factors affecting scores of students

# %%
fig=plt.figure(figsize=(10,6))


student_both[student_both["school"]=="GP"]["G3_x"].hist(alpha=0.3,color="red",bins=30,label="GP")
student_both[student_both["school"]=="MS"]["G3_x"].hist(alpha=0.3,color="blue",bins=30,label="MS")
l=plt.legend()
plt.xlabel("Grades")
plt.ylabel("No. of students")
plt.title("Grade distribution of Maths of students studying both subjects")
#Students of GP school have bimodal distribution and also score high in Maths while studying portuguese also.
# Out:
# Text(0.5, 1.0, 'Grade distribution of Maths of students studying both subjects')

# %%
fig=plt.figure(figsize=(10,6))


student_both[student_both["school"]=="GP"]["G3_y"].hist(alpha=0.3,color="red",bins=30,label="GP")
student_both[student_both["school"]=="MS"]["G3_y"].hist(alpha=0.3,color="blue",bins=30,label="MS")
l=plt.legend()
plt.xlabel("Grades")
plt.ylabel("No. of students")
plt.title("Grade distribution of Portuguese of students studying both subjects")
#Students of GP school have bimodal distribution and also score high in portuguese while studying maths also.
# Out:
# Text(0.5, 1.0, 'Grade distribution of Portuguese of students studying both subjects')

# %%
fig=plt.figure(figsize=(10,6))


student_both[student_both["school"]=="GP"]["studytime"].hist(alpha=0.3,color="red",bins=30,label="GP")
student_both[student_both["school"]=="MS"]["studytime"].hist(alpha=0.3,color="blue",bins=30,label="MS")
l=plt.legend()
plt.xlabel("No of Hours")
plt.ylabel("No. of students")
plt.title("Hours of study given by students studying both subject ")
#On average to study both subjects large number of students find it suitable to study for 2 hours per day
# Out:
# Text(0.5, 1.0, 'Hours of study given by students studying both subject ')

# %%
fig=plt.figure(figsize=(10,6))


student_both[student_both["school"]=="GP"]["failures"].hist(alpha=0.3,color="red",bins=30,label="GP")
student_both[student_both["school"]=="MS"]["failures"].hist(alpha=0.3,color="blue",bins=30,label="MS")
l=plt.legend()
plt.xlabel("No of past class failure ")
plt.ylabel("No. of students")
plt.title("Past failures of students studying both subjects ")
# Students studying both maths and portuguese tend to have least ( zero) number of failures in past class
# Out:
# Text(0.5, 1.0, 'Past failures of students studying both subjects ')

# %%
fig=plt.figure(figsize=(10,6))


student_both[student_both["school"]=="GP"]["activities"].hist(alpha=0.3,color="red",bins=30,label="GP")
student_both[student_both["school"]=="MS"]["activities"].hist(alpha=0.3,color="blue",bins=30,label="MS")
l=plt.legend()
plt.xlabel("Extra co-curricular activities ")
plt.ylabel("No. of students")
plt.title("Participation of students studying both subjects in co-curricular activities  ")
# seems like less number of students prefer to engage in co-curricular acitivities provided they have to manage to study maths and portuguese
# Out:
# Text(0.5, 1.0, 'Participation of students studying both subjects in co-curricular activities  ')

# %%
fig=plt.figure(figsize=(10,6))


student_both[student_both["school"]=="GP"]["absences"].hist(alpha=0.3,color="red",bins=30,label="GP")
student_both[student_both["school"]=="MS"]["absences"].hist(alpha=0.3,color="blue",bins=30,label="MS")
l=plt.legend()
plt.xlabel("No. of absences ")
plt.ylabel("No. of students")
plt.title("Absences of students studying both subjects ")
# Less number of students studying both subjects were absent in the classes
# Out:
# Text(0.5, 1.0, 'Absences of students studying both subjects ')

# %%
#EDA for students studying maths and portuguese for respective schools

# %%
#school performance GP
fig=plt.figure(figsize=(10,6))


student_maths[student_maths["school"]=="GP"]["G3_x"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="GP"]["G3_y"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Grades ")
plt.ylabel("No. of students")
plt.title("Performance graph of GP school students(one subject respectively)")
# Large number of students score better in Portuguese as compared to maths in GP school
#Also Maths has significant number of students scoring 0 Grades in GP school
# Out:
# Text(0.5, 1.0, 'Performance graph of GP school students(one subject respectively)')

# %%
#school performance MS
fig=plt.figure(figsize=(10,6))


student_maths[student_maths["school"]=="MS"]["G3_x"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="MS"]["G3_y"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Grades ")
plt.ylabel("No. of students")
plt.title("Performance graph of MS school students(one subject respectively)")
#Large number of students scoring 0 grades in both Maths and portuguese in MS school
#Very few students taking Maths as alone subject to study in MS school
# Out:
# Text(0.5, 1.0, 'Performance graph of MS school students(one subject respectively)')

# %%
fig=plt.figure(figsize=(10,6))


student_maths[student_maths["school"]=="MS"]["sex"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="MS"]["sex"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Gender")
plt.ylabel("No. of students")
plt.title("Gender distribution of  MS school students(one subject respectively)")
# Out:
# Text(0.5, 1.0, 'Gender distribution of  MS school students(one subject respectively)')

# %%
fig=plt.figure(figsize=(10,6))

student_maths[student_maths["school"]=="GP"]["sex"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="GP"]["sex"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Gender")
plt.ylabel("No. of students")
plt.title("Gender distribution of  GP school students(one subject respectively)")
# Out:
# Text(0.5, 1.0, 'Gender distribution of  GP school students(one subject respectively)')

# %%
fig=plt.figure(figsize=(10,6))

student_maths[student_maths["school"]=="GP"]["address"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="GP"]["address"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Rural/Urban")
plt.ylabel("No. of students")
plt.title("GP school students(one subject respectively) address urban/rural")
# More number of students come from Urban background in GP school
# Out:
# Text(0.5, 1.0, 'GP school students(one subject respectively) address urban/rural')

# %%
fig=plt.figure(figsize=(10,6))

student_maths[student_maths["school"]=="MS"]["address"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="MS"]["address"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Rural/Urban")
plt.ylabel("No. of students")
plt.title("MS school students(one subject respectively) address urban/rural")
# Comparable number of students come from rural and urban area in MS school which shows that MS school is definitely affordable by diffrent economic backgrounds
# Out:
# Text(0.5, 1.0, 'MS school students(one subject respectively) address urban/rural')

# %%
figure=plt.figure(figsize=(10,6))


sns.jointplot(x="traveltime",y="G1_x",data=student_both,dropna=True,kind="hex",color="blue",alpha=0.7)
plt.title("Travel time and Grade relation for Maths subject in both schools",y=0.98,x=0.1)
# Less travel time implies  larger(denser hex) number of students securing mean Grade
# Out:
# Text(0.1, 0.98, 'Travel time and Grade relation for Maths subject in both schools')

# %%
figure=plt.figure(figsize=(10,6))


sns.jointplot(x="traveltime",y="G1_y",data=student_both,dropna=True,kind="hex",color="blue",alpha=0.7)
plt.title("Travel time and Grade relation for Portuguese subject in both schools",y=0.98,x=0.1)
# Less travel time implies  larger(denser hex) number of students securing mean Grade
# Out:
# Text(0.1, 0.98, 'Travel time and Grade relation for Portuguese subject in both schools')

# %%
figure=plt.figure(figsize=(10,6))


sns.jointplot(x="absences",y="G1_x",data=student_both,dropna=True,kind="hex",color="blue",alpha=0.7)
plt.title("Effect of absence on Maths grade in both schools",y=0.98,x=0.1)
# Larger concentration of students having 0 absence and securing average Grades in Maths in both schools
# Out:
# Text(0.1, 0.98, 'Effect of absence on Maths grade in both schools')

# %%
fig=plt.figure(figsize=(10,6))

student_maths[student_maths["school"]=="MS"]["internet"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="MS"]["internet"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Internet access")
plt.ylabel("No. of students")
plt.title("MS school students(one subject respectively) having internet access")
#noticeable number of students dont have access to internet at home since many students in MS school come from rural background as shown in earlier plot
# Out:
# Text(0.5, 1.0, 'MS school students(one subject respectively) having internet access')

# %%
fig=plt.figure(figsize=(10,6))

student_maths[student_maths["school"]=="GP"]["internet"].hist(alpha=0.3,color="red",bins=30,label="Maths")
student_port[student_port["school"]=="GP"]["internet"].hist(alpha=0.3,color="blue",bins=30,label="Portuguese")
l=plt.legend()
plt.xlabel("Internet access")
plt.ylabel("No. of students")
plt.title("GP school students(one subject respectively) having internet access")
#negligible number of student dont have access to internt at home of GP school
# Out:
# Text(0.5, 1.0, 'GP school students(one subject respectively) having internet access')

# %%
#Creating a new column in student_final and filling in categorical values dependingon whether a student studied maths or portuguese.
list_sub=[]
for k in student_final["G1_x"]:
    if k ==0:
        list_sub.append("Por")
    else:
        list_sub.append("Mat")
        
student_final["subject"]=list_sub
student_final.info()
student_final.head(60)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1005 entries, 0 to 1004
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1005 non-null   object
#  1   sex         1005 non-null   object
#  2   age         1005 non-null   int64
#  3   address     1005 non-null   object
#  4   famsize     1005 non-null   object
#  5   Pstatus     1005 non-null   object
#  6   Medu        1005 non-null   int64
#  7   Fedu        1005 non-null   int64
#  8   Mjob        1005 non-null   object
#  9   Fjob        1005 non-null   object
#  10  reason      1005 non-null   object
#  11  guardian    1005 non-null   object
#  12  traveltime  1005 non-null   int64
#  13  studytime   1005 non-null   int64
#  14  failures    1005 non-null   int64
#  15  schoolsup   1005 non-null   object
#  16  famsup      1005 non-null   object
#  17  paid        1005 non-null   object
#  18  activities  1005 non-null   object
# ...

# %%
#Creating some Pivot table

# %%
student_final["G2"]=student_final["G2_x"]+student_final["G2_y"]
student_final["G3"]=student_final["G3_x"]+student_final["G3_y"]
student_final["G1"]=student_final["G1_x"]+student_final["G1_y"]
student_final.head(10)


heatmap_1=student_final.pivot_table(values="G3",index=["school","subject"],columns=["address"],aggfunc="mean")

sns.heatmap(heatmap_1,annot=True)
plt.title("Mean grades of students of both schools based on address")
# Heatmap shows that mean average grades of students from urban area were higher
# Out:
# Text(0.5, 1.0, 'Mean grades of students of both schools based on address')

# %%
heatmap_2=student_final.pivot_table(values="G3",index=["school","subject"],columns=["famsize"],aggfunc="mean")

sns.heatmap(heatmap_2,annot=True)
plt.title("Family size and Grades relation")
#Less family size shows better grades
# Out:
# Text(0.5, 1.0, 'Family size and Grades relation')

# %%
heatmap_4=student_final.pivot_table(values="G3",index=["school","subject"],columns=["traveltime"],aggfunc="mean")

sns.heatmap(heatmap_4,annot=True)
plt.title("Travel time and grades relation")
# with increase in travel time grades are affected in maths
# Out:
# Text(0.5, 1.0, 'Travel time and grades relation')

# %%
heatmap_5=student_final.pivot_table(values="G3",index=["school","subject"],columns=["studytime"],aggfunc="mean")

sns.heatmap(heatmap_5,annot=True)
plt.title("Study time and grades relation")
#With increase in study time the grades of portuguese subject increase significantly
# Out:
# Text(0.5, 1.0, 'Study time and grades relation')

# %%
heatmap_6=student_final.pivot_table(values="G3",index=["school","subject"],columns=["internet"],aggfunc="mean")

sns.heatmap(heatmap_6,annot=True)
plt.title("Internet access and grades relation")
#With access to internet better grades are observed
# Out:
# Text(0.5, 1.0, 'Internet access and grades relation')

# %%
heatmap_7=student_final.pivot_table(values="G3",index=["school","subject"],columns=["famsup"],aggfunc="mean")

sns.heatmap(heatmap_7,annot=True)
plt.title("Family support and grades relations")
#Family supoort for education shows better grades
# Out:
# Text(0.5, 1.0, 'Family support and grades relations')

# %%
heatmap_9=student_final.pivot_table(values="G3",index=["school","subject"],columns=["romantic"],aggfunc="mean")

sns.heatmap(heatmap_9,annot=True)
plt.title("Romantic relation and grades")
#Students not in romantic relation show better grades in subjects
# Out:
# Text(0.5, 1.0, 'Romantic relation and grades')

# %%
heatmap_10=student_final.pivot_table(values="G3",index=["school","subject"],columns=["goout"],aggfunc="mean")

sns.heatmap(heatmap_10,annot=True)
plt.title("Outside Time and grades relation")
#Overall decrease in grade can be observed due to increase in outside time
# Out:
# Text(0.5, 1.0, 'Outside Time and grades relation')

# %%
heatmap_13=student_final.pivot_table(values="G3",index=["school","subject"],columns=["Mjob"],aggfunc="mean")

sns.heatmap(heatmap_13,annot=True)
plt.title("Mother's job and grades relation")
# student's mother working in health sector score comparatively better
# Out:
# Text(0.5, 1.0, "Mother's job and grades relation")

# %%
heatmap_14=student_final.pivot_table(values="G3",index=["school","subject"],columns=["Fjob"],aggfunc="mean")

sns.heatmap(heatmap_14,annot=True)
plt.title("Father's job and grades relation")
# student's father working as teacher score higher grade
# Out:
# Text(0.5, 1.0, "Father's job and grades relation")

# %%
#LINEAR REGRESSION MODEL FOR PREDICTING GRADES OF STUDENTS IN MATHS AND PORTUGUESE

# %%
student_final.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#    G1_x  G2_x  G3_x  G1_y  G2_y G3_y subject    G2    G3    G1
# 0   5.0   6.0   6.0   0.0   0.0  0.0     Mat   6.0   6.0   5.0
# 1   5.0   5.0   6.0   0.0   0.0  0.0     Mat   5.0   6.0   5.0
# 2   7.0   8.0  10.0   0.0   0.0  0.0     Mat   8.0  10.0   7.0
# 3  15.0  14.0  15.0   0.0   0.0  0.0     Mat  14.0  15.0  15.0
# 4   6.0  10.0  10.0   0.0   0.0  0.0     Mat  10.0  10.0   6.0
#
# [5 rows x 40 columns]

# %%
# get dummies method to convert categorical columns having string values into integer values

school=pd.get_dummies(student_final["school"],drop_first=True)
address=pd.get_dummies(student_final["address"],drop_first=True)
famsize=pd.get_dummies(student_final["famsize"],drop_first=True)
Pstatus=pd.get_dummies(student_final["Pstatus"],drop_first=True)
Mjob=pd.get_dummies(student_final["Mjob"],drop_first=True)
Fjob=pd.get_dummies(student_final["Fjob"],drop_first=True)
romantic=pd.get_dummies(student_final["romantic"],drop_first=True)
internet=pd.get_dummies(student_final["internet"],drop_first=True)
higher=pd.get_dummies(student_final["higher"],drop_first=True)
nursery=pd.get_dummies(student_final["nursery"],drop_first=True)
activities=pd.get_dummies(student_final["activities"],drop_first=True)
paid=pd.get_dummies(student_final["paid"],drop_first=True)

famsup=pd.get_dummies(student_final["famsup"],drop_first=True)

schoolsup=pd.get_dummies(student_final["schoolsup"],drop_first=True)

guardian=pd.get_dummies(student_final["guardian"],drop_first=True)
reason=pd.get_dummies(student_final["reason"],drop_first=True)


student_final.drop(["reason","guardian","schoolsup","famsup","paid","activities","nursery","higher","internet","romantic","Fjob","Mjob","Pstatus","famsize","address","school"],inplace=True,axis=1)

# %%
student_final=pd.concat([student_final,reason,guardian,schoolsup,famsup,paid,activities,nursery,higher,internet,romantic,Fjob,Mjob,Pstatus,famsize,address,school],axis=1)

# %%
student_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1005 entries, 0 to 1004
# Data columns (total 49 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         1005 non-null   object
#  1   age         1005 non-null   int64
#  2   Medu        1005 non-null   int64
#  3   Fedu        1005 non-null   int64
#  4   traveltime  1005 non-null   int64
#  5   studytime   1005 non-null   int64
#  6   failures    1005 non-null   int64
#  7   famrel      1005 non-null   int64
#  8   freetime    1005 non-null   int64
#  9   goout       1005 non-null   int64
#  10  Dalc        1005 non-null   int64
#  11  Walc        1005 non-null   int64
#  12  health      1005 non-null   int64
#  13  absences    1005 non-null   int64
#  14  G1_x        1005 non-null   float64
#  15  G2_x        1005 non-null   float64
#  16  G3_x        1005 non-null   float64
#  17  G1_y        1005 non-null   float64
#  18  G2_y        1005 non-null   float64
# ...

# %%
sex=pd.get_dummies(student_final["sex"],drop_first=True)
student_final.drop(["sex"],axis=1,inplace=True)
student_final=pd.concat([student_final,sex],axis=1)

# %%
# Predicting Maths grades for features given using Linear regression
student_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1005 entries, 0 to 1004
# Data columns (total 49 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         1005 non-null   int64
#  1   Medu        1005 non-null   int64
#  2   Fedu        1005 non-null   int64
#  3   traveltime  1005 non-null   int64
#  4   studytime   1005 non-null   int64
#  5   failures    1005 non-null   int64
#  6   famrel      1005 non-null   int64
#  7   freetime    1005 non-null   int64
#  8   goout       1005 non-null   int64
#  9   Dalc        1005 non-null   int64
#  10  Walc        1005 non-null   int64
#  11  health      1005 non-null   int64
#  12  absences    1005 non-null   int64
#  13  G1_x        1005 non-null   float64
#  14  G2_x        1005 non-null   float64
#  15  G3_x        1005 non-null   float64
#  16  G1_y        1005 non-null   float64
#  17  G2_y        1005 non-null   float64
#  18  G3_y        1005 non-null   float64
# ...

# %%
from sklearn.model_selection import train_test_split
X=student_final.drop(["G1","G2","G3","subject","G1_y","G2_y","G3_y"],axis=1)
Y=student_final["G3_x"]
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
pred=model.predict(x_test)

# %%
sns.distplot((y_test-pred))
# Graph shows that linear regression predicted quite well and most of error tends towards 0 where it peaks
# Out:
# F:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# F:\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='G3_x', ylabel='Density'>

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_test,pred))
print(metrics.mean_squared_error(y_test,pred))
print(np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# 2.6806405255990207
# 14.617707256287547
# 3.8233110331605964

# %%
  # Predicting portuguese grades for features given using Linear regression

# %%
from sklearn.model_selection import train_test_split
X1=student_final.drop(["G1","G2","G3","subject","G1_x","G2_x","G3_x"],axis=1)
Y1=student_final["G3_y"]
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(x_train,y_train)
pred1=model1.predict(x_test)

# %%
sns.distplot((y_test-pred1))
#Error peaks at 0 which shows good predictions
# Out:
# F:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# F:\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='G3_x', ylabel='Density'>

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_test,pred1))
print(metrics.mean_squared_error(y_test,pred1))
print(np.sqrt(metrics.mean_squared_error(y_test,pred1)))
# Out:
# 5.5648140262937665e-15
# 5.534596419917293e-29
# 7.439486823644015e-15

# %%
subject=pd.get_dummies(student_final["subject"],drop_first=True)
student_final.drop(["subject"],axis=1,inplace=True)
student_final=pd.concat([student_final,subject],axis=1)

# %%
# Predicting Grades G3 as column and subject column as categorical value thus not seperately preciting both subjects

from sklearn.model_selection import train_test_split
X2=student_final.drop(["G1_y","G2_y","G3_y","G1_x","G2_x","G3_x"],axis=1)
Y2=student_final["G3"]
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)
from sklearn.linear_model import LinearRegression
model2=LinearRegression()
model2.fit(x_train,y_train)
pred2=model2.predict(x_test)

# %%
sns.distplot((y_test-pred2))
#Error peaks at 0 which shows good predictions
# Out:
# F:\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# F:\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='G3_x', ylabel='Density'>

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(y_test,pred2))
print(metrics.mean_squared_error(y_test,pred2))
print(np.sqrt(metrics.mean_squared_error(y_test,pred2)))
# Out:
# 2.598064969736971e-15
# 1.1023461857498309e-29
# 3.3201599144466384e-15
